# %%
#Fail if Class='L'.

#Parameters june used for MLP
#colour_mlp_space = [
#    Integer(2, 25),    # hideen_layer_size[0], 
#    Integer(2, 25),    # hideen_layer_size[1], 
#    Integer(1300, 2000) # max_iter
#]

#Parameters june used for SVM
#colour_svm_space = [
    #Real(1,100), # C
    #Categorical(['poly', 'rbf']), # kernel
#     Integer(1,6), # degree for 'poly'
#     Real(0,1), # gamma
#     (1,1000), # coef0
#     (True,False), # shrinking
#     (True,False), # probability
#]

#Parameters june used for KNN
#colour_knn_space = [
#    Integer(1, 55),    # n_neighbors=params[0], 
#    Integer(2, 100),    # leaf_size=params[1], 
#    Integer(1, 6)    # p=params[2], 
#]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from skimage.color import lab2rgb
import sys
import heapq
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import skimage.color as skcolor
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import make_pipeline
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
import student_data as student

# %%
def gridKNN(X_train, X_test, y_train, y_test):
    #df = pd.DataFrame()
    accscores = pd.DataFrame()
    #accscores = accscores.append({'algorithm', 'n_neighbors', 'leaf_size', 'score'}, ignore_index=True)

    #ball tree
    for j in range (1, 70):
        for i in range (2, 50):
            model_edu_knn = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=i, leaf_size=j, algorithm='ball_tree'))
            model_edu_knn = model_edu_knn.fit(X_train, y_train)
            y_predict = model_edu_knn.predict(X_test)
            accscores = accscores.append({'algorithm':'ball_tree', 'n_neighbors':i, 'leaf_size':j, 'score':accuracy_score(y_test, y_predict)}, ignore_index=True)

    #KD Tree
    for j in range (1, 70):
        for i in range (2, 50):
            model_edu_knn = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=i, leaf_size=j, algorithm='kd_tree'))
            model_edu_knn = model_edu_knn.fit(X_train, y_train)
            y_predict = model_edu_knn.predict(X_test)
            accscores = accscores.append({'algorithm':'kd_tree', 'n_neighbors':i, 'leaf_size':j, 'score':accuracy_score(y_test, y_predict)}, ignore_index=True)


    for i in range (2, 50):
        model_edu_knn = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=i, algorithm='brute'))
        model_edu_knn = model_edu_knn.fit(X_train, y_train)
        y_predict = model_edu_knn.predict(X_test)
        accscores = accscores.append({'algorithm':'brute', 'n_neighbors':i, 'score':accuracy_score(y_test, y_predict)}, ignore_index=True)
    
    return accscores

# %%
X_train, X_test, y_train, y_test = student.X_train, student.X_test, student.y_train, student.y_test

# %%
#straight up Gaussian as a baseline.

# TODO: build model_rgb to predict y from X.
model_edu_gauss = GaussianNB()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

model_edu_gauss = model_edu_gauss.fit(X_train, y_train)
y_predict = model_edu_gauss.predict(X_test)

# TODO: print model_rgb's accuracy_score
print(accuracy_score(y_test, y_predict))
# Out:
# 0.916666666667
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
studentKnn = gridKNN(X_train, X_test, y_train, y_test)
        
#def gsKNN(input_dim=3):
#    model = KNeighborsClassifier(weights='uniform', n_neighbors=i, leaf_size=25, p=1, input_dim=input_dim, verbose=0)
#
brutescores = studentKnn.loc[accscores['algorithm'] == 'brute']#df.loc[df['column_name'] == some_value]
studentKnn = studentKnn.sort_values('score', ascending=False)
studentKnn
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\pipeline.py:270: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
#       algorithm  leaf_size  n_neighbors     score
# 670   ball_tree       14.0         48.0  0.968750
# 4391    kd_tree       23.0         25.0  0.968750
# 983   ball_tree       21.0         25.0  0.968750
# 263   ball_tree        6.0         25.0  0.968750
# 5399    kd_tree       44.0         25.0  0.968750
# 6334    kd_tree       63.0         48.0  0.968750
# 4750    kd_tree       30.0         48.0  0.968750
# 4775    kd_tree       31.0         25.0  0.968750
# 2542  ball_tree       53.0         48.0  0.968750
# 5374    kd_tree       43.0         48.0  0.968750
# 6359    kd_tree       64.0         25.0  0.968750
# 3383    kd_tree        2.0         25.0  0.968750
# 1463  ball_tree       31.0         25.0  0.968750
# 526   ball_tree       11.0         48.0  0.968750
# 1774  ball_tree       37.0         48.0  0.968750
# 3358    kd_tree        1.0         48.0  0.968750
# 3886    kd_tree       12.0         48.0  0.968750
# 5662    kd_tree       49.0         48.0  0.968750
# 238   ball_tree        5.0         48.0  0.968750
# 791   ball_tree       17.0         25.0  0.968750
# 2519  ball_tree       53.0         25.0  0.968750
# 4798    kd_tree       31.0         48.0  0.968750
# 1751  ball_tree       37.0         25.0  0.968750
# 4702    kd_tree       29.0         48.0  0.968750
# 3838    kd_tree       11.0         48.0  0.968750
# 1511  ball_tree       32.0         25.0  0.968750
# 5422    kd_tree       44.0         48.0  0.968750
# 6311    kd_tree       63.0         25.0  0.968750
# 286   ball_tree        6.0         48.0  0.968750
# 503   ball_tree       11.0         25.0  0.968750
# ...         ...        ...          ...       ...
# 5040    kd_tree       37.0          2.0  0.895833
# 6384    kd_tree       65.0          2.0  0.895833
# 1248  ball_tree       27.0          2.0  0.895833
# 240   ball_tree        6.0          2.0  0.895833
# 3936    kd_tree       14.0          2.0  0.895833
# 1056  ball_tree       23.0          2.0  0.895833
# 336   ball_tree        8.0          2.0  0.895833
# 6240    kd_tree       62.0          2.0  0.895833
# 5280    kd_tree       42.0          2.0  0.895833
# 3984    kd_tree       15.0          2.0  0.895833
# 1104  ball_tree       24.0          2.0  0.895833
# 3216  ball_tree       68.0          2.0  0.895833
# 5232    kd_tree       41.0          2.0  0.895833
# 2688  ball_tree       57.0          2.0  0.895833
# 6288    kd_tree       63.0          2.0  0.895833
# 4032    kd_tree       16.0          2.0  0.895833
# 5184    kd_tree       40.0          2.0  0.895833
# 1152  ball_tree       25.0          2.0  0.895833
# 288   ball_tree        7.0          2.0  0.895833
# 2016  ball_tree       43.0          2.0  0.895833
# 4080    kd_tree       17.0          2.0  0.895833
# 3168  ball_tree       67.0          2.0  0.895833
# 6336    kd_tree       64.0          2.0  0.895833
# 5136    kd_tree       39.0          2.0  0.895833
# 1200  ball_tree       26.0          2.0  0.895833
# 5088    kd_tree       38.0          2.0  0.895833
# 1968  ball_tree       42.0          2.0  0.895833
# 4128    kd_tree       18.0          2.0  0.895833
# 2736  ball_tree       58.0          2.0  0.895833
# 0     ball_tree        1.0          2.0  0.895833
#
# [6672 rows x 4 columns]

# %%
#Import Color Data.
# data = pd.read_csv(sys.argv[1])
#data = pd.read_csv("colour-data.csv")
#X = data[['R', 'G', 'B']].values / 255
#y = data['Label'].values
#X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
colourKNN = gridKNN(X_train, X_test, y_train, y_test)

# %%
colourKNN = colourKNN.sort_values('score', ascending=False)
colourKNN
# Out:
#       algorithm  leaf_size  n_neighbors     score
# 6185    kd_tree       60.0         43.0  0.724960
# 281   ball_tree        6.0         43.0  0.724960
# 3401    kd_tree        2.0         43.0  0.724960
# 953   ball_tree       20.0         43.0  0.724960
# 41    ball_tree        1.0         43.0  0.724960
# 4553    kd_tree       26.0         43.0  0.724960
# 4937    kd_tree       34.0         43.0  0.724960
# 5369    kd_tree       43.0         43.0  0.724960
# 2441  ball_tree       51.0         43.0  0.724960
# 5417    kd_tree       44.0         43.0  0.724960
# 4073    kd_tree       16.0         43.0  0.724960
# 6329    kd_tree       63.0         43.0  0.724960
# 5033    kd_tree       36.0         43.0  0.724960
# 4697    kd_tree       29.0         43.0  0.724960
# 665   ball_tree       14.0         43.0  0.724960
# 2153  ball_tree       45.0         43.0  0.724960
# 2297  ball_tree       48.0         43.0  0.724960
# 4169    kd_tree       18.0         43.0  0.724960
# 3929    kd_tree       13.0         43.0  0.724960
# 3257  ball_tree       68.0         43.0  0.724960
# 2537  ball_tree       53.0         43.0  0.724960
# 5177    kd_tree       39.0         43.0  0.724960
# 6281    kd_tree       62.0         43.0  0.724960
# 2057  ball_tree       43.0         43.0  0.724960
# 5273    kd_tree       41.0         43.0  0.724960
# 569   ball_tree       12.0         43.0  0.724960
# 6425    kd_tree       65.0         43.0  0.724960
# 1433  ball_tree       30.0         43.0  0.724960
# 2921  ball_tree       61.0         43.0  0.724960
# 6233    kd_tree       61.0         43.0  0.724960
# ...         ...        ...          ...       ...
# 3072  ball_tree       65.0          2.0  0.666137
# 6096    kd_tree       59.0          2.0  0.666137
# 480   ball_tree       11.0          2.0  0.666137
# 96    ball_tree        3.0          2.0  0.666137
# 6144    kd_tree       60.0          2.0  0.666137
# 3024  ball_tree       64.0          2.0  0.666137
# 3408    kd_tree        3.0          2.0  0.666137
# 6480    kd_tree       67.0          2.0  0.666137
# 6288    kd_tree       63.0          2.0  0.666137
# 6192    kd_tree       61.0          2.0  0.666137
# 3360    kd_tree        2.0          2.0  0.666137
# 336   ball_tree        8.0          2.0  0.666137
# 2832  ball_tree       60.0          2.0  0.666137
# 384   ball_tree        9.0          2.0  0.666137
# 6240    kd_tree       62.0          2.0  0.666137
# 3168  ball_tree       67.0          2.0  0.666137
# 3792    kd_tree       11.0          2.0  0.666137
# 2880  ball_tree       61.0          2.0  0.666137
# 6336    kd_tree       64.0          2.0  0.666137
# 288   ball_tree        7.0          2.0  0.666137
# 2928  ball_tree       62.0          2.0  0.666137
# 432   ball_tree       10.0          2.0  0.666137
# 6384    kd_tree       65.0          2.0  0.666137
# 240   ball_tree        6.0          2.0  0.666137
# 3264  ball_tree       69.0          2.0  0.666137
# 6432    kd_tree       66.0          2.0  0.666137
# 192   ball_tree        5.0          2.0  0.666137
# 2976  ball_tree       63.0          2.0  0.666137
# 3216  ball_tree       68.0          2.0  0.666137
# 6528    kd_tree       68.0          2.0  0.666137
#
# [6672 rows x 4 columns]

# %%
model_edu_svc = make_pipeline(StandardScaler(),
                             SVC(kernel='linear', C=2.0))    

accscores = []

for i in range (-5, 5):
    model_edu_svc = make_pipeline(StandardScaler(), SVC(kernel='linear', C=2.0 * 10 ** (i)))
    
    model_edu_svc = model_edu_svc.fit(X_train, y_train)
    y_predict = model_edu_svc.predict(X_test)
    accscores.append(accuracy_score(y_test, y_predict))
#svc_rgb_model = SVC(kernel='linear', C=2.0)
    #svc_lab_model = make_pipeline(FunctionTransformer(to_lab),
#                                 SVC(kernel='linear', C=2.0))
# Out:
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jonathan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print(heapq.nlargest(5, accscores))

accscores = []
# Out:
# [0.94791666666666663, 0.94791666666666663, 0.94791666666666663, 0.94791666666666663, 0.94791666666666663]
